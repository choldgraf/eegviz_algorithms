# %%
import numpy as np
import scipy as sp
import mne
import pandas as pd
import datetime as dt
from dateutil.relativedelta import relativedelta
import api as api
# import MySQLdb as sql
# import psycopg2 as pg
# import sqlalchemy as sql

# %%
dump_path = './sensors_dump.csv'
df = api.read_dump(dump_path)
Fs = 512

# %% [markdown]
# ## A few simplevisualizations to look at

# %%
ax = df.signal_quality.hist(bins=100)
ax.set_xlim([-1, 100])
ax.set_title('Distribution of signal quality')

# %% [markdown]
# ## Aggregate data and pull out values of interest

# %%
# Time variables that might be interesting
t_slice = pd.DateOffset(seconds=100000)
now = dt.datetime.now()

# %%
vals_df = []
for ix, row in df.iloc[np.random.randint(0, df.shape[0], 1000), :].iterrows():
    vals = api.extract_raw_values(row)
    
    ## Could extract some feature here and just return one value ##
    
    # Create time index for given set of vals, assuming Fs is 512Hz
    vals_ix = pd.date_range(df.index[0], periods=vals.shape[0], freq='2ms')
    id_ix = [row['username']] * len(vals_ix)
    columns = ['raw_values']
    new_ix = pd.MultiIndex.from_arrays([vals_ix, id_ix], names=['time', 'id'])
    vals_df.append(pd.DataFrame(vals, index=new_ix, columns=columns))
vals_df = pd.concat(vals_df)

# %%
vals = api.extract_raw_values(df.query('signal_quality > -1').iloc[15, :])
f, (ax, ax1) = plt.subplots(1, 2, figsize=(15, 5))
ax.plot(vals)
_ = psd(vals, Fs=512)

# %%
api.extract_band(vals_df.iloc[:1000].squeeze(), Fs, 'beta', kind='power')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-61437482279a> in <module>()
# ----> 1 api.extract_band(vals_df.iloc[:1000].squeeze(), Fs, 'beta', kind='power')
#
# NameError: name 'Fs' is not defined

# %%
psd, freqs_psd = extract_freq_power(vals_df.iloc[:5000].squeeze(), Fs)

# %%
plot(freqs_psd, psd)

# %%
grp = vals_df.groupby(level='id')

# %%
Fs = 512

# %%
vals_df.groupby(level='id').apply(extract_band, Fs, 'alpha')
# Out:
# /Users/choldgraf/anaconda/lib/python2.7/site-packages/mne/filter.py:305: UserWarning: Attenuation at stop frequency 7.5Hz is only 20.0dB.
#   '%0.1fdB.' % (att_freq, att_db))
# /Users/choldgraf/anaconda/lib/python2.7/site-packages/mne/filter.py:175: DeprecationWarning: Implicitly casting between incompatible kinds. In a future numpy release, this will raise an error. Use casting="unsafe" if this is intentional.
#   x_filtered[seg_idx * n_seg:seg_idx * n_seg + n_fft] += prod
# /Users/choldgraf/anaconda/lib/python2.7/site-packages/mne/filter.py:178: DeprecationWarning: Implicitly casting between incompatible kinds. In a future numpy release, this will raise an error. Use casting="unsafe" if this is intentional.
#   x_filtered[seg_idx * n_seg:] += prod[:n_x - seg_idx * n_seg]
# id
# Neme             [[-59, -81, -101, -120, -136, -149, -159, -167...
# billyfrese       [[1, 10, 18, 28, 37, 45, 53, 61, 68, 75, 81, 8...
# chuang           [[0, -11, -21, -32, -41, -50, -57, -63, -67, -...
# ...

# %% [markdown]
# # Database stuff

# %%
con = pg.connect(host='localhost:5432', password='AAaa123!', user='postgres')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-fc8273d0127d> in <module>()
# ----> 1 con = pg.connect(host='localhost:5432', password='AAaa123!', user='postgres')
#
# NameError: name 'pg' is not defined

# %%
pg.connect()
# Out:
# <connection object at 0x112f44050; dsn: 'user=postgres password=xxxxxxxx host=localhost', closed: 0>

# %%
eng = sql.create_engine('mysql:///data.sql')

# %%
sql.connect('127.0.0.1:3306')
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-19-fe1fc003e1a3> in <module>()
# ----> 1 sql.connect('127.0.0.1:3306')
#
# /Users/choldgraf/anaconda/lib/python2.7/site-packages/MySQLdb/__init__.pyc in Connect(*args, **kwargs)
#      79     """Factory function for connections.Connection."""
#      80     from MySQLdb.connections import Connection
# ---> 81     return Connection(*args, **kwargs)
#      82
#      83 connect = Connection = Connect
#
# /Users/choldgraf/anaconda/lib/python2.7/site-packages/MySQLdb/connections.pyc in __init__(self, *args, **kwargs)
#     191         autocommit = kwargs2.pop('autocommit', False)
#     192
# --> 193         super(Connection, self).__init__(*args, **kwargs2)
#     194         self.cursorclass = cursorclass
#     195         self.encoders = dict([ (k, v) for k, v in conv.items()
#
# ...

# %%
database = './data.sql'

# %%
pd.io.sql.

# %%
df = pd.read_sql(database, )
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-dcfdfb3de976> in <module>()
# ----> 1 df = pd.read_sql(database)
#
# TypeError: read_sql() takes at least 2 arguments (1 given)
